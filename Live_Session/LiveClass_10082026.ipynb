# %%
# comment

# %%
print("Line one")


# print/output

print("NFSU")
print("10")
# Out:
# Line one
# NFSU
# 10

# %%
# input

input("Enter your name: ")
# Out:
# 'ABCD'

# %%
x = 10
print(x)

# %%
name = input("Enter name: ")
print(name)
# Out:
# abcd

# %%
x = 10
print(type(x))

x = 22.05
print(type(x))

x = "abcd"
print(type(x))

x = False
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# - Can contain letters, digits and underscores (_)
# - First character cannot be a digit
# - Keywords cannot be used as variable names

x123_ = 10
X_1 = 10
True1 = 10

# %%
# arithmetic operators

s = 10+20
print(s)

s = 10 - 20
print(s)

s = 10 * 20
print(s)

s = 10 / 20
print(s)

s = 15 % 7
print(s)
# Out:
# 30
# -10
# 200
# 0.5
# 1

# %%
k = 124.5 // 5.3
print(k)
# Out:
# 23.0

# %%
k = 10 + 10.0
print(k)
print(type(k))
# Out:
# 20.0
# <class 'float'>

# %%
# relational ops

s1 = 10 < 20
print(s1)


s1 = 10 <= 10
print(s1)


s1 = 10 == 10
print(s1)


s1 = 10 != 10
print(s1)
# Out:
# True
# True
# True
# False

# %%
s1 = 10 == 10 #true statement
print(s1)


s2 = not s1
print(s2)
# Out:
# True
# False

# %%
# logical ops

s1 = (10<20) and (20!=20) or (not (30>=5))
print(s1)
# Out:
# False
